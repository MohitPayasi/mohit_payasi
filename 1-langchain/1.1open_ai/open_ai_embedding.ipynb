# %%
# 1st you have to create api for using OPEN AI

# %%
import os
from dotenv import  load_dotenv
load_dotenv()
# Out:
# True

# %%
#os.environ['open_api_key']=os.getenv('OPENAI_API_KEY')
from langchain_openai import OpenAIEmbeddings
embedding=OpenAIEmbeddings(model='text-embedding-3-large')
text= 'this isn open ai embedding'
query_result=embedding.embed_query(text)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[23], line 3
#       1 #os.environ['open_api_key']=os.getenv('OPENAI_API_KEY')
#       2 from langchain_openai import OpenAIEmbeddings
# ----> 3 embedding=OpenAIEmbeddings(model='text-embedding-3-large')
#       4 text= 'this isn open ai embedding'
#       5 query_result=embedding.embed_query(text)
#
#     [... skipping hidden 1 frame]
#
# File d:\mohit_payasi\langchain\venv\Lib\site-packages\langchain_openai\embeddings\base.py:454, in OpenAIEmbeddings.validate_environment(self)
#     449         self.http_async_client = httpx.AsyncClient(proxy=self.openai_proxy)
#     450     async_specific = {
#     451         "http_client": self.http_async_client,
#     452         "api_key": async_api_key_value,
#     453     }
# --> 454     self.async_client = openai.AsyncOpenAI(
#     455         **client_params,
# ...

# %%
query_result=embedding.embed_query(text,dimensions=1024)

# %%
from langchain_community.document_loaders import TextLoader
loader= TextLoader('speech.txt')
docs=loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="Hello is a common word used to greet people.People say hello when they answer the\nphone.You can also use it to get someone's attention.Watch this short video to learn how the word \nhello became the standard way to answer the phone")]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter= RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
final_document= text_splitter.split_documents(docs)
final_document
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="Hello is a common word used to greet people.People say hello when they answer the\nphone.You can also use it to get someone's attention.Watch this short video to learn how the word \nhello became the standard way to answer the phone")]

# %%
from langchain_community.vectorstores import Chroma
db=Chroma.from_documents(final_documnet,embedding)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 from langchain_community.vectorstores import Chroma
# ----> 2 db=Chroma.from_documents(final_documnet,embedding)
#
# NameError: name 'embedding' is not defined
