# %%
import sys
print('Python path:', sys.executable)
print('Python version:', sys.version)
# Out:
# Python path: d:\mohit_payasi\langchain\venv\Scripts\python.exe
# Python version: 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]

# %%
import langchain_community
# Out:
# C:\Users\hpvic\AppData\Local\Temp\ipykernel_15144\3809297631.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   import langchain_community

# %%
# Out:
# Environment loaded!
