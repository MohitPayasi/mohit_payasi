# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader('XYZ.pdf')
pdf_data= loader.load()
print(pdf_data)
# Out:
# C:\Users\hpvic\AppData\Local\Temp\ipykernel_26576\2802854374.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# ...

# %%
#how to recursively split text by character
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
final_document=text_splitter.split_documents(pdf_data)
final_document[0]
# Out:
# Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-09-13T11:44:01+00:00', 'author': '', 'keywords': '', 'moddate': '2026-09-13T11:44:01+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'XYZ.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Mohit Payasi\n8085724062|itsmpayasi04@gmail.com|linkedin.com/in/mohit-payasi-|github.com/MohitPayasi\nSummary\nDetail-oriented AI Professional with a strong foundation in mathematics, statistical modeling, and deep learning.\nExperienced in building scalable machine learning pipelines, training neural networks, and deploying end-to-end AI\nsolutions across diverse domains. Proficient in TensorFlow, PyTorch, and LangChain with a focus on NLP, computer\nvision, and real-time inference systems.\nSkills')

# %%
from langchain_community.document_loaders import TextLoader
loader= TextLoader('speech.txt')
loader.load()
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="Hello is a common word used to greet people.People say hello when they answer the\nphone.You can also use it to get someone's attention.Watch this short video to learn how the word \nhello became the standard way to answer the phone")]

# %%
speech=''
with open ('speech.txt') as f:
    speech=f.read()

# %%
text_splitter= RecursiveCharacterTextSplitter(chunk_size=50,chunk_overlap=20)
text_splitter.create_documents([speech])
# Out:
# [Document(metadata={}, page_content='Hello is a common word used to greet people.People'),
#  Document(metadata={}, page_content='greet people.People say hello when they answer'),
#  Document(metadata={}, page_content='when they answer the'),
#  Document(metadata={}, page_content="phone.You can also use it to get someone's"),
#  Document(metadata={}, page_content="it to get someone's attention.Watch this short"),
#  Document(metadata={}, page_content='this short video to learn how the word'),
#  Document(metadata={}, page_content='hello became the standard way to answer the phone')]

# %%
# character text splitter

# %%
from langchain_text_splitters import CharacterTextSplitter
text_splitter=CharacterTextSplitter(chunk_size=100,chunk_overlap=20)
text=text_splitter.create_documents([speech])
text[0]
# Out:
# Document(metadata={}, page_content="Hello is a common word used to greet people.People say hello when they answer the\nphone.You can also use it to get someone's attention.Watch this short video to learn how the word \nhello became the standard way to answer the phone")

# %%
# html text splitter

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
header_to_split_on=[
    ("h1",'Header 1'),
     ("h2",'Header 2'),
      ("h3",'Header 3'),
]

html_spitter=HTMLHeaderTextSplitter(headers_to_split_on=header_to_split_on)
print(html_spitter.split_text(html_string))
html_string= """<!doctype html>
<html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-IN">
    <head>
        <meta charset="UTF-8">
        <meta content="origin" name="referrer">
        <link href="//www.gstatic.com/images/branding/searchlogo/ico/favicon.ico" rel="icon">
        <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image">
        <title>html data - Google Search</title>
        <script nonce="_cyqOU-M56QGjqmazTrUfg">
            window._hst = Date.now();
        </script>
        <script nonce="_cyqOU-M56QGjqmazTrUfg">
            (function() {
                var _g = {
                    kEI: 'cFmzarnsNoCahvcPrKiEmQw',
                    kEXPI: '31',
                    u: 'b61f448b',
                    kBL: '1EBH',
                    kOPI: 89978449
                };
                (function() {
                    var a;
                    ((a = window.google) == null ? 0 : a.stvsc) ? google.kEI = _g.kEI : window.google = _g;
                }
                ).call(this);
            }
            )();
            (function() {
                google.sn = 'web';
                google.kHL = 'en-IN';
                google.usb = true;
            }
           
                (function() {
                    var m = {};
                    var a = m;
                    if (window.W_jd)
                        for (var b in a)
                            window.W_jd[b] = a[b];
                    else
                        window.W_jd = a;
                }
                )();
            </script>
            <div id="dbg_"></div>
        </div>
        <div jscontroller="j1wVHf" jsaction="rcuQ6b:npT2md"></div>
        <div jscontroller="I9y8sd" jsaction="rcuQ6b:npT2md"> </div>
        <span jscontroller="DLOxie" data-cte="" jsaction="rcuQ6b:npT2md" style="display:none"></span>
        <div jsname="VTXK3c" data-ved="0ahUKEwi55Iu88oOXAxUAjeEIHSwUIcMQi7EMCJgD"></div>
    </body>
</html>
'"""
# Out:
# [Document(metadata={}, page_content='html \'  \nhtml data - Google Search  \nwindow._hst = Date.now();  \n(function() {\n                var _g = {\n                    kEI: \'cFmzarnsNoCahvcPrKiEmQw\',\n                    kEXPI: \'31\',\n                    u: \'b61f448b\',\n                    kBL: \'1EBH\',\n                    kOPI: 89978449\n                };\n                (function() {\n                    var a;\n                    ((a = window.google) == null ? 0 : a.stvsc) ? google.kEI = _g.kEI : window.google = _g;\n                }\n                ).call(this);\n            }\n            )();\n            (function() {\n                google.sn = \'web\';\n                google.kHL = \'en-IN\';\n                google.usb = true;\n            }\n            )();\n            (function() {\n                var h = this || self;\n                var k = /#|$/;\n                function l(a, c) {\n                    var d = a.search(k);\n                    a: {\n
# ...

# %%
header_to_split_on=[
    ("h1",'Header 1'),
     ("h2",'Header 2'),
      ("h3",'Header 3'),
]

html_spitter=HTMLHeaderTextSplitter(headers_to_split_on=header_to_split_on)
print(html_spitter.split_text(html_string))
# Out:
# [Document(metadata={}, page_content="html '  \nhtml data - Google Search  \nwindow._hst = Date.now();  \n(function() {\n                var _g = {\n                    kEI: 'cFmzarnsNoCahvcPrKiEmQw',\n                    kEXPI: '31',\n                    u: 'b61f448b',\n                    kBL: '1EBH',\n                    kOPI: 89978449\n                };\n                (function() {\n                    var a;\n                    ((a = window.google) == null ? 0 : a.stvsc) ? google.kEI = _g.kEI : window.google = _g;\n                }\n                ).call(this);\n            }\n            )();\n            (function() {\n                google.sn = 'web';\n                google.kHL = 'en-IN';\n                google.usb = true;\n            }\n\n                (function() {\n                    var m = {};\n                    var a = m;\n                    if (window.W_jd)\n                        for (var b in a)\n                            window.W_jd[b] = a[b];\n   
# ...

# %%
url='https://developer.mozilla.org/en-US/docs/Web/HTML/How_to/Use_data_attributes'
header_to_split_on=[
    ("h1",'Header 1'),
     ("h2",'Header 2'),
      ("h3",'Header 3'),
]

html_splitter=HTMLHeaderTextSplitter(headers_to_split_on=header_to_split_on)
html_header_split=html_splitter.split_text_from_url(url)

# %%
# html JSON DATA
import pandas as pd
pd.read_csv('speech.txt').to_json('speech.json')

# %%
json=''
with open ('speech.json') as f:
    json=f.read()

# %%
from langchain_text_splitters import RecursiveJsonSplitter
splitter=RecursiveJsonSplitter(max_chunk_size=20)
json_chunk=splitter.split_json(splitter)
for i in json_chunk[:3]:
    print(i)
